# %% [markdown]
# # Import Libaries and fetch data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
path="Resources/US_Data.csv"
fields = ['FOD1P','SCHL','WAGP','AGEP','COW']
coarse_data=pd.read_csv(path, skipinitialspace=True, usecols=fields)
coarse_data['FOD1P'] = coarse_data['FOD1P'].astype(str)
coarse_data.head()
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     FOD1P  SCHL      WAGP  AGEP  COW
# 0  6107.0  21.0   39000.0    63  3.0
# 1  3600.0  21.0   16000.0    22  2.0
# 2  6107.0  21.0  100000.0    52  1.0
# 3  3700.0  21.0   41000.0    65  1.0
# 4  2300.0  21.0   15000.0    33  1.0

# %%
coarse_data['FOD1P'].value_counts()
# Out:
# 2300.0       143321
# 6107.0       142481
# 6201.0       132941
# 3600.0       115702
# 5506.0        82457
# 5501.0        72111
# 6206.0        71299
# 2102.0        64064
# 6207.0        62909
# No_Degree     60000
# 5507.0        59514
# 2414.0        55551
# 3700.0        51447
# 5003.0        44418
# 2406.0        33553
# 2405.0        21123
# 6108.0        19156
# 6100.0        10497
# 1301.0        10415
# 5601.0         5956
# 3202.0         5266
# 3702.0         2809
# Name: FOD1P, dtype: int64

# %% [markdown]
# # Clean the Data

# %%
education_attainment = [24.0,22.0,21.0]
refined_data = coarse_data.loc[coarse_data['SCHL'].isin(education_attainment)].copy()
refined_data['SCHL'].value_counts()
# Out:
# 21.0    730828
# 22.0    311388
# 24.0     60873
# Name: SCHL, dtype: int64

# %%
refined_data.head()
# Out:
#     FOD1P  SCHL      WAGP  AGEP  COW
# 0  6107.0  21.0   39000.0    63  3.0
# 1  3600.0  21.0   16000.0    22  2.0
# 2  6107.0  21.0  100000.0    52  1.0
# 3  3700.0  21.0   41000.0    65  1.0
# 4  2300.0  21.0   15000.0    33  1.0

# %% [markdown]
# # Replace code values with descriptive text

# %%
bachelors_tuition = 24116
masters_tuition = 35000
phd_tuition = 0
refined_data["Tuition"] = np.where(refined_data.SCHL == 21.0, bachelors_tuition,
                                 np.where(refined_data.SCHL == 22.0, masters_tuition,
                                          np.where(refined_data.SCHL == 24.0, phd_tuition, "NA")))

refined_data["SCHL"] = np.where(refined_data.SCHL == 21.0, "Bachelors_Degree",
                                 np.where(refined_data.SCHL == 22.0, "Masters_Degree",
                                          np.where(refined_data.SCHL == 24.0, "PHD", "NA")))
refined_data.head()
# Out:
#     FOD1P              SCHL      WAGP  AGEP  COW Tuition
# 0  6107.0  Bachelors_Degree   39000.0    63  3.0   24116
# 1  3600.0  Bachelors_Degree   16000.0    22  2.0   24116
# 2  6107.0  Bachelors_Degree  100000.0    52  1.0   24116
# 3  3700.0  Bachelors_Degree   41000.0    65  1.0   24116
# 4  2300.0  Bachelors_Degree   15000.0    33  1.0   24116

# %%
refined_data["SCHL"].value_counts()
# Out:
# Bachelors_Degree    730828
# Masters_Degree      311388
# PHD                  60873
# Name: SCHL, dtype: int64

# %%
degree_dict={'2102.0':'Computer Science',
            '3700.0':'Mathematics' ,
            '3702.0':'Statistics and Decision Science', 
            '2405.0':'Chemical Engineering',
            '2406.0':'Civil Engineering',
            '2414.0':'Mechanical Engineering', 
            '3600.0':'Biology', 
            '1301.0':'Environmental', 
            '5003.0':'Chemistry', 
            '5501.0':'Economics', 
            '5506.0':'Political Science', 
            '5507.0':'Sociology', 
            '2300.0':'General Education', 
            '3202.0':'Law', 
            '5601.0':'Construction Services', 
            '6201.0':'Accounting', 
            '6207.0':'Finance', 
            '6206.0':'Marketing and Marketing Research', 
            '6108.0':'Pharmacy, Pharmaceutical Sciences and Administration',
            '6107.0':'Nursing', 
            '6100.0':'General Medical Health Services',
            'No_Degree':'No_Degree'}
refined_data['FOD1P'] = refined_data['FOD1P'].map(degree_dict)
refined_data.head()
# Out:
#                FOD1P              SCHL      WAGP  AGEP  COW Tuition
# 0            Nursing  Bachelors_Degree   39000.0    63  3.0   24116
# 1            Biology  Bachelors_Degree   16000.0    22  2.0   24116
# 2            Nursing  Bachelors_Degree  100000.0    52  1.0   24116
# 3        Mathematics  Bachelors_Degree   41000.0    65  1.0   24116
# 4  General Education  Bachelors_Degree   15000.0    33  1.0   24116

# %%
refined_data['FOD1P'].value_counts()
# Out:
# General Education                                       137846
# Nursing                                                 135644
# Accounting                                              126376
# Biology                                                  87238
# Marketing and Marketing Research                         69893
# Economics                                                64790
# Political Science                                        63855
# Computer Science                                         62839
# Finance                                                  59981
# Sociology                                                56049
# Mechanical Engineering                                   53793
# Mathematics                                              48459
# Chemistry                                                36709
# Civil Engineering                                        32400
# Chemical Engineering                                     19852
# Pharmacy, Pharmaceutical Sciences and Administration     14881
# Environmental                                             9954
# General Medical Health Services                           9654
# Construction Services                                     5875
# Law                                                       4289
# Statistics and Decision Science                           2712
# Name: FOD1P, dtype: int64

# %%
# rename columns
rename_df = refined_data.copy()
rename_df.rename(columns = {'FOD1P':'Field of Study', 
                               'SCHL':'Educational Attainment', 
                               'WAGP':'Income', 'AGEP':'Age', 
                               'COW':'Class of Worker'}, inplace=True)
rename_df.head()
# Out:
#       Field of Study Educational Attainment    Income  Age  Class of Worker  \
# 0            Nursing       Bachelors_Degree   39000.0   63              3.0
# 1            Biology       Bachelors_Degree   16000.0   22              2.0
# 2            Nursing       Bachelors_Degree  100000.0   52              1.0
# 3        Mathematics       Bachelors_Degree   41000.0   65              1.0
# 4  General Education       Bachelors_Degree   15000.0   33              1.0
#
#   Tuition
# 0   24116
# 1   24116
# 2   24116
# 3   24116
# 4   24116

# %%
rename_df.columns
# Out:
# Index(['Field of Study', 'Educational Attainment', 'Income', 'Age',
#        'Class of Worker', 'Tuition'],
#       dtype='object')

# %%
rename_df.groupby('Field of Study')['Income'].max()
# Out:
# Field of Study
# Accounting                                              736000.0
# Biology                                                 710000.0
# Chemical Engineering                                    714000.0
# Chemistry                                               665000.0
# Civil Engineering                                       710000.0
# Computer Science                                        714000.0
# Construction Services                                   613000.0
# Economics                                               736000.0
# Environmental                                           655000.0
# Finance                                                 736000.0
# General Education                                       665000.0
# General Medical Health Services                         637000.0
# Law                                                     613000.0
# Marketing and Marketing Research                        714000.0
# Mathematics                                             714000.0
# Mechanical Engineering                                  710000.0
# Nursing                                                 655000.0
# Pharmacy, Pharmaceutical Sciences and Administration    665000.0
# Political Science                                       736000.0
# Sociology                                               736000.0
# Statistics and Decision Science                         665000.0
# Name: Income, dtype: float64

# %%
rename_df.groupby(['Field of Study', 'Educational Attainment' ])['Income'].min();

# %%
grouped_df=rename_df.groupby(['Field of Study', 'Educational Attainment' ])

# %%
income_percentile=rename_df.groupby(['Field of Study', 'Educational Attainment' ])['Income'].quantile(.5)

# %%
income_percentile;

# %%
pindex=income_percentile.index
for i in range(len(pindex)):
    rename_df.loc[(rename_df['Field of Study'] == pindex[i][0]) & 
                              (rename_df['Educational Attainment'] == pindex[i][1]) & 
                             (rename_df['Income'] >= income_percentile[i]), ['Income']]=999999999

# %%
new_rename_df=rename_df[rename_df['Income']!=999999999]

# %%
rename_df.groupby(['Field of Study', 'Educational Attainment' ])['Income'].max()
# Out:
# Field of Study                                        Educational Attainment
# Accounting                                            Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Biology                                               Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Chemical Engineering                                  Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Chemistry                                             Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Civil Engineering                                     Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Computer Science                                      Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Construction Services                                 Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Economics                                             Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Environmental                                         Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Finance                                               Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
#                                                                                    ...
# General Medical Health Services                       Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Law                                                   Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Marketing and Marketing Research                      Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Mathematics                                           Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Mechanical Engineering                                Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Nursing                                               Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Pharmacy, Pharmaceutical Sciences and Administration  Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Political Science                                     Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Sociology                                             Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Statistics and Decision Science                       Bachelors_Degree          999999999.0
#                                                       Masters_Degree            999999999.0
#                                                       PHD                       999999999.0
# Name: Income, Length: 63, dtype: float64

# %%
new_rename_df.groupby(['Field of Study', 'Educational Attainment' ])['Income'].max()
# Out:
# Field of Study                                        Educational Attainment
# Accounting                                            Bachelors_Degree           39900.0
#                                                       Masters_Degree             61000.0
#                                                       PHD                        50000.0
# Biology                                               Bachelors_Degree           24900.0
#                                                       Masters_Degree             44900.0
#                                                       PHD                        69000.0
# Chemical Engineering                                  Bachelors_Degree           51000.0
#                                                       Masters_Degree             70000.0
#                                                       PHD                        84000.0
# Chemistry                                             Bachelors_Degree           20600.0
#                                                       Masters_Degree             35900.0
#                                                       PHD                        64000.0
# Civil Engineering                                     Bachelors_Degree           55000.0
#                                                       Masters_Degree             69000.0
#                                                       PHD                        69000.0
# Computer Science                                      Bachelors_Degree           68000.0
#                                                       Masters_Degree             89000.0
#                                                       PHD                       105000.0
# Construction Services                                 Bachelors_Degree           59000.0
#                                                       Masters_Degree             64000.0
#                                                       PHD                        34000.0
# Economics                                             Bachelors_Degree           37900.0
#                                                       Masters_Degree             55000.0
#                                                       PHD                        73000.0
# Environmental                                         Bachelors_Degree           34900.0
#                                                       Masters_Degree             54000.0
#                                                       PHD                        69000.0
# Finance                                               Bachelors_Degree           51000.0
#                                                       Masters_Degree             77000.0
#                                                       PHD                        69000.0
#                                                                                   ...
# General Medical Health Services                       Bachelors_Degree           25600.0
#                                                       Masters_Degree             51000.0
#                                                       PHD                        61000.0
# Law                                                   Bachelors_Degree           31700.0
#                                                       Masters_Degree             39000.0
#                                                       PHD                        41000.0
# Marketing and Marketing Research                      Bachelors_Degree           39900.0
#                                                       Masters_Degree             53000.0
#                                                       PHD                        49700.0
# Mathematics                                           Bachelors_Degree           22900.0
#                                                       Masters_Degree             35900.0
#                                                       PHD                        60000.0
# Mechanical Engineering                                Bachelors_Degree           59000.0
#                                                       Masters_Degree             84000.0
#                                                       PHD                        89000.0
# Nursing                                               Bachelors_Degree           43900.0
#                                                       Masters_Degree             64000.0
#                                                       PHD                        73000.0
# Pharmacy, Pharmaceutical Sciences and Administration  Bachelors_Degree           39600.0
#                                                       Masters_Degree             46000.0
#                                                       PHD                        99000.0
# Political Science                                     Bachelors_Degree           32900.0
#                                                       Masters_Degree             49900.0
#                                                       PHD                        59000.0
# Sociology                                             Bachelors_Degree           20900.0
#                                                       Masters_Degree             29800.0
#                                                       PHD                        39600.0
# Statistics and Decision Science                       Bachelors_Degree           39500.0
#                                                       Masters_Degree             59000.0
#                                                       PHD                        83000.0
# Name: Income, Length: 63, dtype: float64

# %%
rename_df=rename_df[rename_df['Income']>0]

# %%
rename_df.boxplot(by = "Field of Study", column = ["Income"], rot = 90)

# %% [markdown]
# # Create DataFrames for plotting

# %% [markdown]
# ### for mean data

# %%
comment = '''    
What I need:
dictionary_template = { "Field0":[bachelor_income_mean, bachelor_income_std, 
                                  master_income_mean, master_income_std,
                                  phd_income_mean, phd_income_std ],
                        "Field1":[bachelor_income_mean, bachelor_income_std, 
                                  master_income_mean, master_income_std,
                                  phd_income_mean, phd_income_std ], .... }
'''
field_mean_std_df = rename_df.copy()
mean_sr = field_mean_std_df.groupby(['Field of Study', 'Educational Attainment' ])['Income'].mean()
mean_df = mean_sr.to_frame()
# rounding the mean values to 2 decimal places
mean_df.rename(columns={'Income':'Mean'}, inplace=True)
mean_df['Mean'] = mean_df['Mean'].apply(lambda x: round(x, 2))
mean_df

#for display
mean_pivt = mean_df.pivot_table(index='Educational Attainment', columns='Field of Study', values='Mean')
mean_pivt
# Out:
# Field of Study          Accounting   Biology  Chemical Engineering  Chemistry  \
# Educational Attainment
# Bachelors_Degree          58513.32  38824.20              69208.28   41516.11
# Masters_Degree            82731.09  56473.68              88943.39   57298.30
# PHD                       80158.99  97400.19              98375.90   88141.87
#
# Field of Study          Civil Engineering  Computer Science  \
# Educational Attainment
# Bachelors_Degree                 65334.55          75923.86
# Masters_Degree                   82412.33          96926.06
# PHD                              80231.42         127073.19
#
# Field of Study          Construction Services  Economics  Environmental  \
# Educational Attainment
# Bachelors_Degree                     72303.08   65990.67       45125.49
# Masters_Degree                       78276.62   92381.57       63289.30
# PHD                                  44896.43   99615.67       79176.86
#
# Field of Study            Finance  ...  General Medical Health Services  \
# Educational Attainment             ...
# Bachelors_Degree         76557.24  ...                         35628.08
# Masters_Degree          105986.74  ...                         56443.63
# PHD                     100025.74  ...                         70276.52
#
# Field of Study               Law  Marketing and Marketing Research  \
# Educational Attainment
# Bachelors_Degree        42900.33                          57108.58
# Masters_Degree          51377.62                          73418.89
# PHD                     72775.14                          68725.07
#
# Field of Study          Mathematics  Mechanical Engineering   Nursing  \
# Educational Attainment
# Bachelors_Degree           47518.30                67435.37  44267.35
# Masters_Degree             57880.33                92748.39  64989.60
# PHD                        82008.13                95814.38  81972.48
#
# Field of Study          Pharmacy, Pharmaceutical Sciences and Administration  \
# Educational Attainment
# Bachelors_Degree                                                 59415.19
# Masters_Degree                                                   66742.14
# PHD                                                             101906.14
#
# Field of Study          Political Science  Sociology  \
# Educational Attainment
# Bachelors_Degree                 53530.06   34323.26
# Masters_Degree                   68410.70   41135.92
# PHD                              80181.81   57357.32
#
# Field of Study          Statistics and Decision Science
# Educational Attainment
# Bachelors_Degree                               58661.08
# Masters_Degree                                 73366.30
# PHD                                           101136.55
#
# [3 rows x 21 columns]

# %%
# box plot
mean_pivt.boxplot(column = ["Accounting", "Biology", "General Education", "Nursing", 
                           "Marketing and Marketing Research", "Economics", "Political Science", "Computer Science",
                           "Finance", "Sociology", "Mechanical Engineering", "Mathematics", "Chemistry", 
                           "Civil Engineering", "Chemical Engineering", 
                           "Pharmacy, Pharmaceutical Sciences and Administration", "Environmental", 
                           "General Medical Health Services", "Construction Services", "Law"], rot =90)

# %% [markdown]
# ### for std data

# %%
std_sr = field_mean_std_df.groupby(['Field of Study', 'Educational Attainment' ])['Income'].std()
std_df = std_sr.to_frame()
# rounding the mean values to 2 decimal places
std_df.rename(columns={'Income':'std'}, inplace=True)
std_df['std'] = std_df['std'].apply(lambda x: round(x, 2))
std_df

#for display
std_pivt = std_df.pivot_table(index='Educational Attainment', columns='Field of Study', values='std')
std_pivt
# Out:
# Field of Study          Accounting    Biology  Chemical Engineering  \
# Educational Attainment
# Bachelors_Degree          80956.36   53952.02              85138.84
# Masters_Degree            98381.62   69790.21             106401.08
# PHD                      105062.91  110537.70             108109.52
#
# Field of Study          Chemistry  Civil Engineering  Computer Science  \
# Educational Attainment
# Bachelors_Degree         62449.77           75703.50          74201.40
# Masters_Degree           78389.52           92644.57          88597.23
# PHD                     105599.79           89736.59         117378.51
#
# Field of Study          Construction Services  Economics  Environmental  \
# Educational Attainment
# Bachelors_Degree                     72888.15  100016.38       53030.16
# Masters_Degree                       83697.44  126551.66       64950.53
# PHD                                  48940.22  121749.74       80447.89
#
# Field of Study            Finance  ...  General Medical Health Services  \
# Educational Attainment             ...
# Bachelors_Degree         97064.86  ...                         45018.86
# Masters_Degree          120688.58  ...                         53702.66
# PHD                     121610.82  ...                         73736.85
#
# Field of Study                Law  Marketing and Marketing Research  \
# Educational Attainment
# Bachelors_Degree         57744.28                          74616.49
# Masters_Degree           61667.14                          88340.26
# PHD                     105616.12                          86189.76
#
# Field of Study          Mathematics  Mechanical Engineering   Nursing  \
# Educational Attainment
# Bachelors_Degree           72817.15                75645.45  43189.49
# Masters_Degree             83072.46                96840.92  61054.13
# PHD                       102599.98                95899.16  87827.07
#
# Field of Study          Pharmacy, Pharmaceutical Sciences and Administration  \
# Educational Attainment
# Bachelors_Degree                                                 69728.28
# Masters_Degree                                                   81963.52
# PHD                                                              90140.29
#
# Field of Study          Political Science  Sociology  \
# Educational Attainment
# Bachelors_Degree                 79715.85   51087.99
# Masters_Degree                   89812.41   55663.16
# PHD                             100376.22   76604.44
#
# Field of Study          Statistics and Decision Science
# Educational Attainment
# Bachelors_Degree                               76163.23
# Masters_Degree                                 88088.44
# PHD                                           102574.64
#
# [3 rows x 21 columns]

# %%
# box plot
std_pivt.boxplot(column = ["Accounting", "Biology", "General Education", "Nursing", 
                           "Marketing and Marketing Research", "Economics", "Political Science", "Computer Science",
                           "Finance", "Sociology", "Mechanical Engineering", "Mathematics", "Chemistry", 
                           "Civil Engineering", "Chemical Engineering", 
                           "Pharmacy, Pharmaceutical Sciences and Administration", "Environmental", 
                           "General Medical Health Services", "Construction Services", "Law"], rot =90)

# %%
mean_df_cpy = mean_df.copy()
std_df_cpy = std_df.copy()
mean_df_cpy.reset_index(inplace=True)
std_df_cpy.reset_index(inplace=True)
# create consolidated dictionary for plotting
data_dict = {}
FOS_list = mean_df_cpy['Field of Study'].unique().tolist()

#std_df_cpy[std_df_cpy['Field of Study'] == 'Nursing']
data_dict[''] = ['Bachelor Degree Mean', 'Bachelor Degree std', 
                          'Masters Degree Mean', 'Masters Degree Mean', 
                          'PhD Mean', 'PhD Mean']
for fos in FOS_list:
    bs_mean = mean_df_cpy[(mean_df_cpy['Field of Study'] == fos) & \
           (mean_df_cpy['Educational Attainment'] == 'Bachelors_Degree')]['Mean'].tolist()[0]
    bs_std = std_df_cpy[(std_df_cpy['Field of Study'] == fos) & \
           (std_df_cpy['Educational Attainment'] == 'Bachelors_Degree')]['std'].tolist()[0]
    
    ms_mean = mean_df_cpy[(mean_df_cpy['Field of Study'] == fos) & \
           (mean_df_cpy['Educational Attainment'] == 'Masters_Degree')]['Mean'].tolist()[0]
    ms_std = std_df_cpy[(std_df_cpy['Field of Study'] == fos) & \
           (std_df_cpy['Educational Attainment'] == 'Masters_Degree')]['std'].tolist()[0]
    
    phd_mean = mean_df_cpy[(mean_df_cpy['Field of Study'] == fos) & \
           (mean_df_cpy['Educational Attainment'] == 'PHD')]['Mean'].tolist()[0]
    phd_std = std_df_cpy[(std_df_cpy['Field of Study'] == fos) & \
           (std_df_cpy['Educational Attainment'] == 'PHD')]['std'].tolist()[0]
    
    data_dict[fos] = [bs_mean, bs_std, ms_mean, ms_std, phd_mean, phd_std]
    
comment = '''
The data_dict template is:
{<field labe>:<list of values>}

{'Field of study':[ bachelors_degree_mean, bachelors_degree_std, 
                    masters_degree_mean, masters_degree_std, 
                    PhD_mean, PhD_std ]  
}
'''    
#from pprint import pprint
#pprint(data_dict)

# %%
data_df = pd.DataFrame(data_dict)
data_df.set_index('')
# Out:
#                       Accounting    Biology  Chemical Engineering  Chemistry  \
#
# Bachelor Degree Mean    58513.32   38824.20              69208.28   41516.11
# Bachelor Degree std     80956.36   53952.02              85138.84   62449.77
# Masters Degree Mean     82731.09   56473.68              88943.39   57298.30
# Masters Degree Mean     98381.62   69790.21             106401.08   78389.52
# PhD Mean                80158.99   97400.19              98375.90   88141.87
# PhD Mean               105062.91  110537.70             108109.52  105599.79
#
#                       Civil Engineering  Computer Science  \
#
# Bachelor Degree Mean           65334.55          75923.86
# Bachelor Degree std            75703.50          74201.40
# Masters Degree Mean            82412.33          96926.06
# Masters Degree Mean            92644.57          88597.23
# PhD Mean                       80231.42         127073.19
# PhD Mean                       89736.59         117378.51
#
#                       Construction Services  Economics  Environmental  \
#
# Bachelor Degree Mean               72303.08   65990.67       45125.49
# Bachelor Degree std                72888.15  100016.38       53030.16
# Masters Degree Mean                78276.62   92381.57       63289.30
# Masters Degree Mean                83697.44  126551.66       64950.53
# PhD Mean                           44896.43   99615.67       79176.86
# PhD Mean                           48940.22  121749.74       80447.89
#
#                         Finance  ...  General Medical Health Services  \
#                                  ...
# Bachelor Degree Mean   76557.24  ...                         35628.08
# Bachelor Degree std    97064.86  ...                         45018.86
# Masters Degree Mean   105986.74  ...                         56443.63
# Masters Degree Mean   120688.58  ...                         53702.66
# PhD Mean              100025.74  ...                         70276.52
# PhD Mean              121610.82  ...                         73736.85
#
#                             Law  Marketing and Marketing Research  \
#
# Bachelor Degree Mean   42900.33                          57108.58
# Bachelor Degree std    57744.28                          74616.49
# Masters Degree Mean    51377.62                          73418.89
# Masters Degree Mean    61667.14                          88340.26
# PhD Mean               72775.14                          68725.07
# PhD Mean              105616.12                          86189.76
#
#                       Mathematics  Mechanical Engineering   Nursing  \
#
# Bachelor Degree Mean     47518.30                67435.37  44267.35
# Bachelor Degree std      72817.15                75645.45  43189.49
# Masters Degree Mean      57880.33                92748.39  64989.60
# Masters Degree Mean      83072.46                96840.92  61054.13
# PhD Mean                 82008.13                95814.38  81972.48
# PhD Mean                102599.98                95899.16  87827.07
#
#                       Pharmacy, Pharmaceutical Sciences and Administration  \
#
# Bachelor Degree Mean                                           59415.19
# Bachelor Degree std                                            69728.28
# Masters Degree Mean                                            66742.14
# Masters Degree Mean                                            81963.52
# PhD Mean                                                      101906.14
# PhD Mean                                                       90140.29
#
#                       Political Science  Sociology  \
#
# Bachelor Degree Mean           53530.06   34323.26
# Bachelor Degree std            79715.85   51087.99
# Masters Degree Mean            68410.70   41135.92
# Masters Degree Mean            89812.41   55663.16
# PhD Mean                       80181.81   57357.32
# PhD Mean                      100376.22   76604.44
#
#                       Statistics and Decision Science
#
# Bachelor Degree Mean                         58661.08
# Bachelor Degree std                          76163.23
# Masters Degree Mean                          73366.30
# Masters Degree Mean                          88088.44
# PhD Mean                                    101136.55
# PhD Mean                                    102574.64
#
# [6 rows x 21 columns]
