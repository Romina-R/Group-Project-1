# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import scipy.stats as st
from Plotting_Functions import intersection, plotline

# %%
madeupslope=[45000, 55000, 65000, 85000, 88000, 112000]
madeupintercept=[-45000,-205000,-245000,-345000,-425000]
madeuplegend='Fine Art'

# %%
plotline(madeupslope,madeupintercept,madeuplegend, .50)
